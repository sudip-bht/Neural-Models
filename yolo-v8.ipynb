# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5643.5/8062.4 GB disk)

# %%
from ultralytics import YOLO
from matplotlib import pyplot as plt

# %%
model = YOLO('yolov8n-cls.pt')

# %%
results = model.train(data='/kaggle/input/ham10000-augmented-dataset/Data folder', epochs = 30, imgsz=224)
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
metrics = !yolo val model='/kaggle/working/runs/classify/train2/weights/best.pt' data='/kaggle/input/ham-1000/DataSet' split=test

# %%
metrics = !yolo val model='/kaggle/working/runs/classify/train2/weights/best.pt' data='/kaggle/input/ham-1000/DataSet' split=test

# %% [markdown]
# metrics

# %%
metrics

# %%
import matplotlib.pyplot as plt
from PIL import Image

# Load the normalized confusion matrix image
confusion_matrix_normalized = Image.open("/kaggle/working/runs/classify/val6/confusion_matrix_normalized.png")

# Display the image
plt.imshow(confusion_matrix_normalized)
plt.axis('off')  # Turn off axis labels
plt.show()

# %%
# Provided values
TP = 1541
FP = 114
FN = 72
TN = 1450

# Compute accuracy
accuracy = (TP + TN) / (TP + FP + FN + TN)

# Compute precision
precision = TP / (TP + FP)

# Compute recall
recall = TP / (TP + FN)

# Compute F1-score
f1_score = 2 * (precision * recall) / (precision + recall)

# Print results
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1_score)
# Out:
# Accuracy: 0.9414542020774316
# Precision: 0.9311178247734139
# Recall: 0.9553626782393057
# F1-score: 0.9430844553243574

# %%
TP = 1541
FP = 114
FN = 72
TN = 1450

# Compute Sensitivity (True Positive Rate, Recall)
sensitivity = TP / (TP + FN)

# Compute Specificity
specificity = TN / (TN + FP)

print("Sensitivity (Recall):", sensitivity)
print("Specificity:", specificity)
# Out:
# Sensitivity (Recall): 0.9553626782393057
# Specificity: 0.9271099744245525
